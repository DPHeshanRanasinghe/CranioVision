# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
from pathlib import Path
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

DATASET_ROOT = Path("data/raw/brats2024_small")
